# %% [markdown]
# # Notebook Individual de Data Science
#
# Este notebook pode usar funções compartilhadas do projeto (`src/`).

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parents[3]
sys.path.append(str(PROJECT_ROOT))

from src.data.load_data import load_raw_data
from src.features.preprocess import basic_preprocess

df = load_raw_data()
df = basic_preprocess(df)
df.head()
